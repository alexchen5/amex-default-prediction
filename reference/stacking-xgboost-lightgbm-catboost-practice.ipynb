# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %%
data = pd.read_csv('../input/application_train.csv')
test = pd.read_csv('../input/application_test.csv')
prev = pd.read_csv('../input/previous_application.csv')

# %%
data.head()
# Out:
#    SK_ID_CURR             ...              AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002             ...                                     1.0
# 1      100003             ...                                     0.0
# 2      100004             ...                                     0.0
# 3      100006             ...                                     NaN
# 4      100007             ...                                     0.0
#
# [5 rows x 122 columns]

# %%
categorical_feats = [f for f in data.columns if data[f].dtype == 'object']
print(categorical_feats)
# Out:
# ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'EMERGENCYSTATE_MODE']

# %%
for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    #print(data[f_])
    print(indexer)
    test[f_] = indexer.get_indexer(test[f_])
    #print(test[f_])
# Out:
# Index(['Cash loans', 'Revolving loans'], dtype='object')
# Index(['M', 'F', 'XNA'], dtype='object')
# Index(['N', 'Y'], dtype='object')
# Index(['Y', 'N'], dtype='object')
# Index(['Unaccompanied', 'Family', 'Spouse, partner', 'Children', 'Other_A',
#        'Other_B', 'Group of people'],
#       dtype='object')
# Index(['Working', 'State servant', 'Commercial associate', 'Pensioner',
#        'Unemployed', 'Student', 'Businessman', 'Maternity leave'],
#       dtype='object')
# Index(['Secondary / secondary special', 'Higher education',
#        'Incomplete higher', 'Lower secondary', 'Academic degree'],
#       dtype='object')
# Index(['Single / not married', 'Married', 'Civil marriage', 'Widow',
#        'Separated', 'Unknown'],
#       dtype='object')
# Index(['House / apartment', 'Rented apartment', 'With parents',
#        'Municipal apartment', 'Office apartment', 'Co-op apartment'],
#       dtype='object')
# Index(['Laborers', 'Core staff', 'Accountants', 'Managers', 'Drivers',
#        'Sales staff', 'Cleaning staff', 'Cooking staff',
#        'Private service staff', 'Medicine staff', 'Security staff',
#        'High skill tech staff', 'Waiters/barmen staff', 'Low-skill Laborers',
#        'Realty agents', 'Secretaries', 'IT staff', 'HR staff'],
#       dtype='object')
# Index(['WEDNESDAY', 'MONDAY', 'THURSDAY', 'SUNDAY', 'SATURDAY', 'FRIDAY',
#        'TUESDAY'],
#       dtype='object')
# Index(['Business Entity Type 3', 'School', 'Government', 'Religion', 'Other',
#        'XNA', 'Electricity', 'Medicine', 'Business Entity Type 2',
#        'Self-employed', 'Transport: type 2', 'Construction', 'Housing',
#        'Kindergarten', 'Trade: type 7', 'Industry: type 11', 'Military',
#        'Services', 'Security Ministries', 'Transport: type 4',
#        'Industry: type 1', 'Emergency', 'Security', 'Trade: type 2',
#        'University', 'Transport: type 3', 'Police', 'Business Entity Type 1',
#        'Postal', 'Industry: type 4', 'Agriculture', 'Restaurant', 'Culture',
#        'Hotel', 'Industry: type 7', 'Trade: type 3', 'Industry: type 3',
#        'Bank', 'Industry: type 9', 'Insurance', 'Trade: type 6',
#        'Industry: type 2', 'Transport: type 1', 'Industry: type 12', 'Mobile',
#        'Trade: type 1', 'Industry: type 5', 'Industry: type 10',
#        'Legal Services', 'Advertising', 'Trade: type 5', 'Cleaning',
#        'Industry: type 13', 'Trade: type 4', 'Telecom', 'Industry: type 8',
#        'Realtor', 'Industry: type 6'],
#       dtype='object')
# Index(['reg oper account', 'org spec account', 'reg oper spec account',
#        'not specified'],
#       dtype='object')
# Index(['block of flats', 'terraced house', 'specific housing'], dtype='object')
# Index(['Stone, brick', 'Block', 'Panel', 'Mixed', 'Wooden', 'Others',
#        'Monolithic'],
#       dtype='object')
# Index(['No', 'Yes'], dtype='object')

# %%
gc.enable()

# %%
y_train = data['TARGET']
del data['TARGET']

# %%
prev_cat_features = [f_ for f_ in prev.columns if prev[f_].dtype == 'object']
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

# %%
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

# %%
x_train = x_train.fillna(0)
x_test= x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]
print(ntrain)
# Out:
# 307511

# %%
excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

# %%
kf = KFold(n_splits = NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

# %%
class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
        
class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

# %%
xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 0:	total: 241ms	remaining: 48s
# 1:	total: 419ms	remaining: 41.5s
# 2:	total: 593ms	remaining: 38.9s
# 3:	total: 778ms	remaining: 38.1s
# 4:	total: 948ms	remaining: 37s
# 5:	total: 1.12s	remaining: 36.2s
# 6:	total: 1.29s	remaining: 35.6s
# 7:	total: 1.47s	remaining: 35.2s
# 8:	total: 1.66s	remaining: 35.3s
# 9:	total: 1.84s	remaining: 35s
# 10:	total: 2.01s	remaining: 34.5s
# 11:	total: 2.17s	remaining: 34.1s
# 12:	total: 2.35s	remaining: 33.7s
# 13:	total: 2.51s	remaining: 33.4s
# 14:	total: 2.69s	remaining: 33.2s
# 15:	total: 2.85s	remaining: 32.8s
# 16:	total: 3.02s	remaining: 32.5s
# 17:	total: 3.19s	remaining: 32.3s
# 18:	total: 3.37s	remaining: 32.1s
# 19:	total: 3.58s	remaining: 32.2s
# 20:	total: 3.74s	remaining: 31.9s
# 21:	total: 3.92s	remaining: 31.7s
# 22:	total: 4.1s	remaining: 31.5s
# 23:	total: 4.27s	remaining: 31.3s
# 24:	total: 4.43s	remaining: 31s
# 25:	total: 4.6s	remaining: 30.8s
# 26:	total: 4.78s	remaining: 30.6s
# 27:	total: 4.95s	remaining: 30.4s
# 28:	total: 5.12s	remaining: 30.2s
# 29:	total: 5.29s	remaining: 30s
# 30:	total: 5.46s	remaining: 29.7s
# 31:	total: 5.62s	remaining: 29.5s
# 32:	total: 5.78s	remaining: 29.2s
# 33:	total: 5.96s	remaining: 29.1s
# 34:	total: 6.12s	remaining: 28.9s
# 35:	total: 6.3s	remaining: 28.7s
# 36:	total: 6.46s	remaining: 28.5s
# 37:	total: 6.64s	remaining: 28.3s
# 38:	total: 6.81s	remaining: 28.1s
# 39:	total: 6.97s	remaining: 27.9s
# 40:	total: 7.15s	remaining: 27.7s
# 41:	total: 7.31s	remaining: 27.5s
# 42:	total: 7.48s	remaining: 27.3s
# 43:	total: 7.65s	remaining: 27.1s
# 44:	total: 7.84s	remaining: 27s
# 45:	total: 8.02s	remaining: 26.8s
# 46:	total: 8.18s	remaining: 26.6s
# 47:	total: 8.36s	remaining: 26.5s
# 48:	total: 8.52s	remaining: 26.2s
# 49:	total: 8.68s	remaining: 26s
# 50:	total: 8.87s	remaining: 25.9s
# 51:	total: 9.03s	remaining: 25.7s
# 52:	total: 9.19s	remaining: 25.5s
# 53:	total: 9.36s	remaining: 25.3s
# 54:	total: 9.54s	remaining: 25.1s
# 55:	total: 9.7s	remaining: 24.9s
# 56:	total: 9.86s	remaining: 24.7s
# 57:	total: 10s	remaining: 24.6s
# 58:	total: 10.2s	remaining: 24.4s
# 59:	total: 10.4s	remaining: 24.2s
# 60:	total: 10.6s	remaining: 24s
# 61:	total: 10.7s	remaining: 23.9s
# 62:	total: 10.9s	remaining: 23.7s
# 63:	total: 11.1s	remaining: 23.5s
# 64:	total: 11.2s	remaining: 23.3s
# 65:	total: 11.4s	remaining: 23.1s
# 66:	total: 11.6s	remaining: 22.9s
# 67:	total: 11.7s	remaining: 22.8s
# 68:	total: 11.9s	remaining: 22.6s
# 69:	total: 12.1s	remaining: 22.4s
# 70:	total: 12.2s	remaining: 22.2s
# 71:	total: 12.4s	remaining: 22.1s
# 72:	total: 12.6s	remaining: 21.9s
# 73:	total: 12.8s	remaining: 21.8s
# 74:	total: 12.9s	remaining: 21.6s
# 75:	total: 13.1s	remaining: 21.4s
# 76:	total: 13.3s	remaining: 21.3s
# 77:	total: 13.5s	remaining: 21.1s
# 78:	total: 13.7s	remaining: 21s
# 79:	total: 13.9s	remaining: 20.8s
# 80:	total: 14s	remaining: 20.6s
# 81:	total: 14.2s	remaining: 20.4s
# 82:	total: 14.4s	remaining: 20.3s
# 83:	total: 14.5s	remaining: 20.1s
# 84:	total: 14.7s	remaining: 19.9s
# 85:	total: 14.9s	remaining: 19.7s
# 86:	total: 15s	remaining: 19.5s
# 87:	total: 15.2s	remaining: 19.4s
# 88:	total: 15.4s	remaining: 19.2s
# 89:	total: 15.6s	remaining: 19.1s
# 90:	total: 15.8s	remaining: 18.9s
# 91:	total: 15.9s	remaining: 18.7s
# 92:	total: 16.1s	remaining: 18.5s
# 93:	total: 16.3s	remaining: 18.3s
# 94:	total: 16.4s	remaining: 18.2s
# 95:	total: 16.6s	remaining: 18s
# 96:	total: 16.8s	remaining: 17.8s
# 97:	total: 16.9s	remaining: 17.6s
# 98:	total: 17.1s	remaining: 17.4s
# 99:	total: 17.3s	remaining: 17.3s
# 100:	total: 17.4s	remaining: 17.1s
# 101:	total: 17.6s	remaining: 16.9s
# 102:	total: 17.8s	remaining: 16.8s
# 103:	total: 18s	remaining: 16.6s
# 104:	total: 18.1s	remaining: 16.4s
# 105:	total: 18.3s	remaining: 16.2s
# 106:	total: 18.5s	remaining: 16.1s
# 107:	total: 18.6s	remaining: 15.9s
# 108:	total: 18.8s	remaining: 15.7s
# 109:	total: 19s	remaining: 15.6s
# 110:	total: 19.2s	remaining: 15.4s
# 111:	total: 19.3s	remaining: 15.2s
# 112:	total: 19.5s	remaining: 15s
# 113:	total: 19.7s	remaining: 14.9s
# 114:	total: 19.9s	remaining: 14.7s
# 115:	total: 20.1s	remaining: 14.5s
# 116:	total: 20.2s	remaining: 14.3s
# 117:	total: 20.4s	remaining: 14.2s
# 118:	total: 20.6s	remaining: 14s
# 119:	total: 20.7s	remaining: 13.8s
# 120:	total: 20.9s	remaining: 13.6s
# 121:	total: 21.1s	remaining: 13.5s
# 122:	total: 21.3s	remaining: 13.3s
# 123:	total: 21.4s	remaining: 13.1s
# 124:	total: 21.6s	remaining: 12.9s
# 125:	total: 21.7s	remaining: 12.8s
# 126:	total: 21.9s	remaining: 12.6s
# 127:	total: 22.1s	remaining: 12.4s
# 128:	total: 22.3s	remaining: 12.3s
# 129:	total: 22.5s	remaining: 12.1s
# 130:	total: 22.7s	remaining: 11.9s
# 131:	total: 22.8s	remaining: 11.8s
# 132:	total: 23s	remaining: 11.6s
# 133:	total: 23.2s	remaining: 11.4s
# 134:	total: 23.4s	remaining: 11.3s
# 135:	total: 23.5s	remaining: 11.1s
# 136:	total: 23.7s	remaining: 10.9s
# 137:	total: 23.9s	remaining: 10.7s
# 138:	total: 24s	remaining: 10.6s
# 139:	total: 24.2s	remaining: 10.4s
# 140:	total: 24.4s	remaining: 10.2s
# 141:	total: 24.5s	remaining: 10s
# 142:	total: 24.7s	remaining: 9.85s
# 143:	total: 24.9s	remaining: 9.68s
# 144:	total: 25.1s	remaining: 9.51s
# 145:	total: 25.2s	remaining: 9.33s
# 146:	total: 25.4s	remaining: 9.15s
# 147:	total: 25.6s	remaining: 8.98s
# 148:	total: 25.7s	remaining: 8.8s
# 149:	total: 25.9s	remaining: 8.63s
# 150:	total: 26.1s	remaining: 8.45s
# 151:	total: 26.2s	remaining: 8.28s
# 152:	total: 26.4s	remaining: 8.11s
# 153:	total: 26.6s	remaining: 7.94s
# 154:	total: 26.7s	remaining: 7.76s
# 155:	total: 26.9s	remaining: 7.59s
# 156:	total: 27.1s	remaining: 7.42s
# 157:	total: 27.2s	remaining: 7.24s
# 158:	total: 27.4s	remaining: 7.07s
# 159:	total: 27.6s	remaining: 6.9s
# 160:	total: 27.7s	remaining: 6.72s
# 161:	total: 27.9s	remaining: 6.55s
# 162:	total: 28.1s	remaining: 6.38s
# 163:	total: 28.2s	remaining: 6.2s
# 164:	total: 28.4s	remaining: 6.03s
# 165:	total: 28.6s	remaining: 5.86s
# 166:	total: 28.8s	remaining: 5.68s
# 167:	total: 28.9s	remaining: 5.51s
# 168:	total: 29.1s	remaining: 5.34s
# 169:	total: 29.3s	remaining: 5.17s
# 170:	total: 29.5s	remaining: 5s
# 171:	total: 29.7s	remaining: 4.83s
# 172:	total: 29.8s	remaining: 4.66s
# 173:	total: 30s	remaining: 4.48s
# 174:	total: 30.2s	remaining: 4.31s
# 175:	total: 30.4s	remaining: 4.14s
# 176:	total: 30.5s	remaining: 3.97s
# 177:	total: 30.7s	remaining: 3.79s
# 178:	total: 30.9s	remaining: 3.62s
# 179:	total: 31s	remaining: 3.45s
# 180:	total: 31.2s	remaining: 3.27s
# 181:	total: 31.4s	remaining: 3.1s
# 182:	total: 31.5s	remaining: 2.93s
# 183:	total: 31.7s	remaining: 2.76s
# 184:	total: 31.9s	remaining: 2.58s
# 185:	total: 32s	remaining: 2.41s
# 186:	total: 32.2s	remaining: 2.24s
# 187:	total: 32.4s	remaining: 2.07s
# 188:	total: 32.6s	remaining: 1.9s
# 189:	total: 32.7s	remaining: 1.72s
# 190:	total: 32.9s	remaining: 1.55s
# 191:	total: 33.1s	remaining: 1.38s
# 192:	total: 33.3s	remaining: 1.21s
# 193:	total: 33.5s	remaining: 1.03s
# 194:	total: 33.7s	remaining: 863ms
# 195:	total: 33.8s	remaining: 691ms
# 196:	total: 34s	remaining: 518ms
# 197:	total: 34.2s	remaining: 345ms
# 198:	total: 34.3s	remaining: 173ms
# 199:	total: 34.5s	remaining: 0us
# 0:	total: 183ms	remaining: 36.3s
# 1:	total: 348ms	remaining: 34.4s
# 2:	total: 520ms	remaining: 34.1s
# 3:	total: 696ms	remaining: 34.1s
# 4:	total: 862ms	remaining: 33.6s
# 5:	total: 1.04s	remaining: 33.6s
# 6:	total: 1.21s	remaining: 33.2s
# 7:	total: 1.38s	remaining: 33.1s
# 8:	total: 1.55s	remaining: 32.9s
# 9:	total: 1.74s	remaining: 33.1s
# 10:	total: 1.92s	remaining: 32.9s
# 11:	total: 2.09s	remaining: 32.7s
# 12:	total: 2.27s	remaining: 32.7s
# 13:	total: 2.47s	remaining: 32.8s
# 14:	total: 2.63s	remaining: 32.5s
# 15:	total: 2.79s	remaining: 32.1s
# 16:	total: 2.96s	remaining: 31.9s
# 17:	total: 3.13s	remaining: 31.6s
# 18:	total: 3.3s	remaining: 31.4s
# 19:	total: 3.49s	remaining: 31.4s
# 20:	total: 3.67s	remaining: 31.3s
# 21:	total: 3.84s	remaining: 31.1s
# 22:	total: 4.01s	remaining: 30.9s
# 23:	total: 4.2s	remaining: 30.8s
# 24:	total: 4.36s	remaining: 30.5s
# 25:	total: 4.53s	remaining: 30.3s
# 26:	total: 4.7s	remaining: 30.1s
# 27:	total: 4.89s	remaining: 30s
# 28:	total: 5.04s	remaining: 29.7s
# 29:	total: 5.21s	remaining: 29.5s
# 30:	total: 5.39s	remaining: 29.4s
# 31:	total: 5.56s	remaining: 29.2s
# 32:	total: 5.73s	remaining: 29s
# 33:	total: 5.9s	remaining: 28.8s
# 34:	total: 6.08s	remaining: 28.6s
# 35:	total: 6.27s	remaining: 28.6s
# 36:	total: 6.44s	remaining: 28.4s
# 37:	total: 6.61s	remaining: 28.2s
# 38:	total: 6.78s	remaining: 28s
# 39:	total: 6.93s	remaining: 27.7s
# 40:	total: 7.1s	remaining: 27.5s
# 41:	total: 7.27s	remaining: 27.4s
# 42:	total: 7.45s	remaining: 27.2s
# 43:	total: 7.63s	remaining: 27.1s
# 44:	total: 7.8s	remaining: 26.9s
# 45:	total: 7.96s	remaining: 26.6s
# 46:	total: 8.15s	remaining: 26.5s
# 47:	total: 8.32s	remaining: 26.3s
# 48:	total: 8.5s	remaining: 26.2s
# 49:	total: 8.68s	remaining: 26s
# 50:	total: 8.84s	remaining: 25.8s
# 51:	total: 9.02s	remaining: 25.7s
# 52:	total: 9.19s	remaining: 25.5s
# 53:	total: 9.37s	remaining: 25.3s
# 54:	total: 9.54s	remaining: 25.1s
# 55:	total: 9.7s	remaining: 24.9s
# 56:	total: 9.87s	remaining: 24.8s
# 57:	total: 10s	remaining: 24.6s
# 58:	total: 10.2s	remaining: 24.4s
# 59:	total: 10.4s	remaining: 24.2s
# 60:	total: 10.5s	remaining: 24s
# 61:	total: 10.7s	remaining: 23.8s
# 62:	total: 10.9s	remaining: 23.6s
# 63:	total: 11s	remaining: 23.4s
# 64:	total: 11.2s	remaining: 23.3s
# 65:	total: 11.4s	remaining: 23.1s
# 66:	total: 11.6s	remaining: 22.9s
# 67:	total: 11.7s	remaining: 22.8s
# 68:	total: 11.9s	remaining: 22.6s
# 69:	total: 12.1s	remaining: 22.4s
# 70:	total: 12.2s	remaining: 22.3s
# 71:	total: 12.4s	remaining: 22.1s
# 72:	total: 12.6s	remaining: 21.9s
# 73:	total: 12.8s	remaining: 21.7s
# 74:	total: 12.9s	remaining: 21.6s
# 75:	total: 13.1s	remaining: 21.4s
# 76:	total: 13.3s	remaining: 21.2s
# 77:	total: 13.4s	remaining: 21s
# 78:	total: 13.6s	remaining: 20.8s
# 79:	total: 13.8s	remaining: 20.7s
# 80:	total: 13.9s	remaining: 20.5s
# 81:	total: 14.1s	remaining: 20.3s
# 82:	total: 14.3s	remaining: 20.1s
# 83:	total: 14.5s	remaining: 20s
# 84:	total: 14.6s	remaining: 19.8s
# 85:	total: 14.8s	remaining: 19.6s
# 86:	total: 15s	remaining: 19.5s
# 87:	total: 15.1s	remaining: 19.3s
# 88:	total: 15.3s	remaining: 19.1s
# 89:	total: 15.5s	remaining: 18.9s
# 90:	total: 15.6s	remaining: 18.7s
# 91:	total: 15.8s	remaining: 18.6s
# 92:	total: 16s	remaining: 18.4s
# 93:	total: 16.1s	remaining: 18.2s
# 94:	total: 16.3s	remaining: 18s
# 95:	total: 16.5s	remaining: 17.9s
# 96:	total: 16.7s	remaining: 17.7s
# 97:	total: 16.8s	remaining: 17.5s
# 98:	total: 17s	remaining: 17.4s
# 99:	total: 17.2s	remaining: 17.2s
# 100:	total: 17.4s	remaining: 17s
# 101:	total: 17.5s	remaining: 16.8s
# 102:	total: 17.7s	remaining: 16.6s
# 103:	total: 17.8s	remaining: 16.5s
# 104:	total: 18s	remaining: 16.3s
# 105:	total: 18.2s	remaining: 16.2s
# 106:	total: 18.4s	remaining: 16s
# 107:	total: 18.6s	remaining: 15.8s
# 108:	total: 18.7s	remaining: 15.6s
# 109:	total: 18.9s	remaining: 15.5s
# 110:	total: 19.1s	remaining: 15.3s
# 111:	total: 19.2s	remaining: 15.1s
# 112:	total: 19.4s	remaining: 14.9s
# 113:	total: 19.6s	remaining: 14.8s
# 114:	total: 19.8s	remaining: 14.6s
# 115:	total: 19.9s	remaining: 14.4s
# 116:	total: 20.1s	remaining: 14.3s
# 117:	total: 20.3s	remaining: 14.1s
# 118:	total: 20.4s	remaining: 13.9s
# 119:	total: 20.6s	remaining: 13.7s
# 120:	total: 20.8s	remaining: 13.6s
# 121:	total: 20.9s	remaining: 13.4s
# 122:	total: 21.1s	remaining: 13.2s
# 123:	total: 21.3s	remaining: 13s
# 124:	total: 21.5s	remaining: 12.9s
# 125:	total: 21.6s	remaining: 12.7s
# 126:	total: 21.8s	remaining: 12.5s
# 127:	total: 22s	remaining: 12.4s
# 128:	total: 22.1s	remaining: 12.2s
# 129:	total: 22.3s	remaining: 12s
# 130:	total: 22.5s	remaining: 11.9s
# 131:	total: 22.7s	remaining: 11.7s
# 132:	total: 22.8s	remaining: 11.5s
# 133:	total: 23s	remaining: 11.3s
# 134:	total: 23.2s	remaining: 11.2s
# 135:	total: 23.4s	remaining: 11s
# 136:	total: 23.5s	remaining: 10.8s
# 137:	total: 23.7s	remaining: 10.6s
# 138:	total: 23.8s	remaining: 10.5s
# 139:	total: 24s	remaining: 10.3s
# 140:	total: 24.2s	remaining: 10.1s
# 141:	total: 24.3s	remaining: 9.94s
# 142:	total: 24.5s	remaining: 9.77s
# 143:	total: 24.7s	remaining: 9.6s
# 144:	total: 24.8s	remaining: 9.42s
# 145:	total: 25s	remaining: 9.26s
# 146:	total: 25.2s	remaining: 9.08s
# 147:	total: 25.4s	remaining: 8.91s
# 148:	total: 25.5s	remaining: 8.74s
# 149:	total: 25.7s	remaining: 8.56s
# 150:	total: 25.8s	remaining: 8.38s
# 151:	total: 26s	remaining: 8.21s
# 152:	total: 26.2s	remaining: 8.04s
# 153:	total: 26.4s	remaining: 7.87s
# 154:	total: 26.5s	remaining: 7.7s
# 155:	total: 26.7s	remaining: 7.52s
# 156:	total: 26.8s	remaining: 7.35s
# 157:	total: 27s	remaining: 7.18s
# 158:	total: 27.2s	remaining: 7.01s
# 159:	total: 27.4s	remaining: 6.84s
# 160:	total: 27.5s	remaining: 6.67s
# 161:	total: 27.7s	remaining: 6.5s
# 162:	total: 27.9s	remaining: 6.33s
# 163:	total: 28.1s	remaining: 6.16s
# 164:	total: 28.2s	remaining: 5.99s
# 165:	total: 28.4s	remaining: 5.82s
# 166:	total: 28.6s	remaining: 5.64s
# 167:	total: 28.7s	remaining: 5.47s
# 168:	total: 28.9s	remaining: 5.3s
# 169:	total: 29.1s	remaining: 5.13s
# 170:	total: 29.3s	remaining: 4.96s
# 171:	total: 29.4s	remaining: 4.79s
# 172:	total: 29.6s	remaining: 4.62s
# 173:	total: 29.8s	remaining: 4.45s
# 174:	total: 30s	remaining: 4.28s
# 175:	total: 30.1s	remaining: 4.11s
# 176:	total: 30.3s	remaining: 3.94s
# 177:	total: 30.5s	remaining: 3.77s
# 178:	total: 30.6s	remaining: 3.59s
# 179:	total: 30.8s	remaining: 3.42s
# 180:	total: 31s	remaining: 3.25s
# 181:	total: 31.2s	remaining: 3.08s
# 182:	total: 31.3s	remaining: 2.91s
# 183:	total: 31.5s	remaining: 2.74s
# 184:	total: 31.7s	remaining: 2.57s
# 185:	total: 31.9s	remaining: 2.4s
# 186:	total: 32s	remaining: 2.23s
# 187:	total: 32.2s	remaining: 2.05s
# 188:	total: 32.3s	remaining: 1.88s
# 189:	total: 32.5s	remaining: 1.71s
# 190:	total: 32.7s	remaining: 1.54s
# 191:	total: 32.9s	remaining: 1.37s
# 192:	total: 33s	remaining: 1.2s
# 193:	total: 33.2s	remaining: 1.03s
# 194:	total: 33.4s	remaining: 857ms
# 195:	total: 33.6s	remaining: 685ms
# 196:	total: 33.7s	remaining: 514ms
# 197:	total: 33.9s	remaining: 343ms
# 198:	total: 34.1s	remaining: 171ms
# 199:	total: 34.3s	remaining: 0us
# 0:	total: 180ms	remaining: 35.9s
# 1:	total: 364ms	remaining: 36s
# 2:	total: 549ms	remaining: 36s
# 3:	total: 726ms	remaining: 35.6s
# 4:	total: 912ms	remaining: 35.6s
# 5:	total: 1.1s	remaining: 35.5s
# 6:	total: 1.28s	remaining: 35.4s
# 7:	total: 1.46s	remaining: 35s
# 8:	total: 1.63s	remaining: 34.6s
# 9:	total: 1.8s	remaining: 34.3s
# 10:	total: 1.96s	remaining: 33.7s
# 11:	total: 2.13s	remaining: 33.4s
# 12:	total: 2.31s	remaining: 33.2s
# 13:	total: 2.48s	remaining: 32.9s
# 14:	total: 2.66s	remaining: 32.8s
# 15:	total: 2.96s	remaining: 34s
# 16:	total: 3.13s	remaining: 33.7s
# 17:	total: 3.29s	remaining: 33.2s
# 18:	total: 3.48s	remaining: 33.1s
# 19:	total: 3.64s	remaining: 32.8s
# 20:	total: 3.81s	remaining: 32.5s
# 21:	total: 3.99s	remaining: 32.3s
# 22:	total: 4.15s	remaining: 32s
# 23:	total: 4.32s	remaining: 31.6s
# 24:	total: 4.49s	remaining: 31.5s
# 25:	total: 4.66s	remaining: 31.2s
# 26:	total: 4.83s	remaining: 30.9s
# 27:	total: 5s	remaining: 30.7s
# 28:	total: 5.18s	remaining: 30.5s
# 29:	total: 5.37s	remaining: 30.4s
# 30:	total: 5.54s	remaining: 30.2s
# 31:	total: 5.72s	remaining: 30.1s
# 32:	total: 5.89s	remaining: 29.8s
# 33:	total: 6.09s	remaining: 29.7s
# 34:	total: 6.26s	remaining: 29.5s
# 35:	total: 6.42s	remaining: 29.3s
# 36:	total: 6.61s	remaining: 29.1s
# 37:	total: 6.81s	remaining: 29s
# 38:	total: 6.98s	remaining: 28.8s
# 39:	total: 7.14s	remaining: 28.6s
# 40:	total: 7.31s	remaining: 28.4s
# 41:	total: 7.47s	remaining: 28.1s
# 42:	total: 7.65s	remaining: 27.9s
# 43:	total: 7.81s	remaining: 27.7s
# 44:	total: 7.98s	remaining: 27.5s
# 45:	total: 8.16s	remaining: 27.3s
# 46:	total: 8.33s	remaining: 27.1s
# 47:	total: 8.51s	remaining: 26.9s
# 48:	total: 8.68s	remaining: 26.8s
# 49:	total: 8.85s	remaining: 26.5s
# 50:	total: 9.03s	remaining: 26.4s
# 51:	total: 9.2s	remaining: 26.2s
# 52:	total: 9.37s	remaining: 26s
# 53:	total: 9.54s	remaining: 25.8s
# 54:	total: 9.69s	remaining: 25.6s
# 55:	total: 9.87s	remaining: 25.4s
# 56:	total: 10.1s	remaining: 25.2s
# 57:	total: 10.2s	remaining: 25.1s
# 58:	total: 10.4s	remaining: 24.9s
# 59:	total: 10.6s	remaining: 24.7s
# 60:	total: 10.7s	remaining: 24.5s
# 61:	total: 10.9s	remaining: 24.3s
# 62:	total: 11.1s	remaining: 24.2s
# 63:	total: 11.3s	remaining: 23.9s
# 64:	total: 11.5s	remaining: 23.8s
# 65:	total: 11.6s	remaining: 23.6s
# 66:	total: 11.8s	remaining: 23.4s
# 67:	total: 12s	remaining: 23.2s
# 68:	total: 12.1s	remaining: 23.1s
# 69:	total: 12.3s	remaining: 22.9s
# 70:	total: 12.5s	remaining: 22.7s
# 71:	total: 12.6s	remaining: 22.5s
# 72:	total: 12.8s	remaining: 22.3s
# 73:	total: 13s	remaining: 22.1s
# 74:	total: 13.2s	remaining: 21.9s
# 75:	total: 13.3s	remaining: 21.7s
# 76:	total: 13.5s	remaining: 21.6s
# 77:	total: 13.7s	remaining: 21.4s
# 78:	total: 13.8s	remaining: 21.2s
# 79:	total: 14s	remaining: 21s
# 80:	total: 14.2s	remaining: 20.8s
# 81:	total: 14.3s	remaining: 20.6s
# 82:	total: 14.5s	remaining: 20.5s
# 83:	total: 14.7s	remaining: 20.3s
# 84:	total: 14.9s	remaining: 20.1s
# 85:	total: 15s	remaining: 19.9s
# 86:	total: 15.2s	remaining: 19.8s
# 87:	total: 15.4s	remaining: 19.6s
# 88:	total: 15.6s	remaining: 19.4s
# 89:	total: 15.7s	remaining: 19.2s
# 90:	total: 15.9s	remaining: 19.1s
# 91:	total: 16.1s	remaining: 18.9s
# 92:	total: 16.2s	remaining: 18.7s
# 93:	total: 16.4s	remaining: 18.5s
# 94:	total: 16.6s	remaining: 18.3s
# 95:	total: 16.8s	remaining: 18.2s
# 96:	total: 16.9s	remaining: 18s
# 97:	total: 17.1s	remaining: 17.8s
# 98:	total: 17.3s	remaining: 17.6s
# 99:	total: 17.4s	remaining: 17.4s
# 100:	total: 17.6s	remaining: 17.2s
# 101:	total: 17.8s	remaining: 17.1s
# 102:	total: 17.9s	remaining: 16.9s
# 103:	total: 18.1s	remaining: 16.7s
# 104:	total: 18.3s	remaining: 16.5s
# 105:	total: 18.4s	remaining: 16.4s
# 106:	total: 18.6s	remaining: 16.2s
# 107:	total: 18.8s	remaining: 16s
# 108:	total: 19s	remaining: 15.9s
# 109:	total: 19.1s	remaining: 15.7s
# 110:	total: 19.3s	remaining: 15.5s
# 111:	total: 19.5s	remaining: 15.3s
# 112:	total: 19.7s	remaining: 15.1s
# 113:	total: 19.8s	remaining: 15s
# 114:	total: 20s	remaining: 14.8s
# 115:	total: 20.2s	remaining: 14.6s
# 116:	total: 20.3s	remaining: 14.4s
# 117:	total: 20.5s	remaining: 14.3s
# 118:	total: 20.7s	remaining: 14.1s
# 119:	total: 20.9s	remaining: 13.9s
# 120:	total: 21s	remaining: 13.7s
# 121:	total: 21.2s	remaining: 13.6s
# 122:	total: 21.4s	remaining: 13.4s
# 123:	total: 21.6s	remaining: 13.2s
# 124:	total: 21.7s	remaining: 13s
# 125:	total: 21.9s	remaining: 12.9s
# 126:	total: 22.1s	remaining: 12.7s
# 127:	total: 22.2s	remaining: 12.5s
# 128:	total: 22.4s	remaining: 12.3s
# 129:	total: 22.6s	remaining: 12.2s
# 130:	total: 22.8s	remaining: 12s
# 131:	total: 22.9s	remaining: 11.8s
# 132:	total: 23.1s	remaining: 11.6s
# 133:	total: 23.3s	remaining: 11.5s
# 134:	total: 23.4s	remaining: 11.3s
# 135:	total: 23.6s	remaining: 11.1s
# 136:	total: 23.8s	remaining: 10.9s
# 137:	total: 23.9s	remaining: 10.7s
# 138:	total: 24.1s	remaining: 10.6s
# 139:	total: 24.3s	remaining: 10.4s
# 140:	total: 24.4s	remaining: 10.2s
# 141:	total: 24.6s	remaining: 10s
# 142:	total: 24.8s	remaining: 9.88s
# 143:	total: 24.9s	remaining: 9.7s
# 144:	total: 25.1s	remaining: 9.53s
# 145:	total: 25.3s	remaining: 9.36s
# 146:	total: 25.5s	remaining: 9.18s
# 147:	total: 25.6s	remaining: 9.01s
# 148:	total: 25.8s	remaining: 8.84s
# 149:	total: 26s	remaining: 8.66s
# 150:	total: 26.2s	remaining: 8.49s
# 151:	total: 26.3s	remaining: 8.32s
# 152:	total: 26.5s	remaining: 8.15s
# 153:	total: 26.7s	remaining: 7.98s
# 154:	total: 26.9s	remaining: 7.8s
# 155:	total: 27s	remaining: 7.63s
# 156:	total: 27.2s	remaining: 7.45s
# 157:	total: 27.4s	remaining: 7.28s
# 158:	total: 27.6s	remaining: 7.11s
# 159:	total: 27.8s	remaining: 6.94s
# 160:	total: 27.9s	remaining: 6.76s
# 161:	total: 28.1s	remaining: 6.59s
# 162:	total: 28.3s	remaining: 6.41s
# 163:	total: 28.4s	remaining: 6.24s
# 164:	total: 28.6s	remaining: 6.07s
# 165:	total: 28.8s	remaining: 5.89s
# 166:	total: 28.9s	remaining: 5.72s
# 167:	total: 29.1s	remaining: 5.55s
# 168:	total: 29.3s	remaining: 5.37s
# 169:	total: 29.5s	remaining: 5.2s
# 170:	total: 29.7s	remaining: 5.03s
# 171:	total: 29.8s	remaining: 4.85s
# 172:	total: 30s	remaining: 4.68s
# 173:	total: 30.1s	remaining: 4.5s
# 174:	total: 30.3s	remaining: 4.33s
# 175:	total: 30.5s	remaining: 4.16s
# 176:	total: 30.7s	remaining: 3.98s
# 177:	total: 30.8s	remaining: 3.81s
# 178:	total: 31s	remaining: 3.64s
# 179:	total: 31.2s	remaining: 3.46s
# 180:	total: 31.3s	remaining: 3.29s
# 181:	total: 31.5s	remaining: 3.12s
# 182:	total: 31.7s	remaining: 2.94s
# 183:	total: 31.8s	remaining: 2.77s
# 184:	total: 32s	remaining: 2.59s
# 185:	total: 32.2s	remaining: 2.42s
# 186:	total: 32.3s	remaining: 2.25s
# 187:	total: 32.5s	remaining: 2.08s
# 188:	total: 32.7s	remaining: 1.9s
# 189:	total: 32.8s	remaining: 1.73s
# 190:	total: 33s	remaining: 1.56s
# 191:	total: 33.2s	remaining: 1.38s
# 192:	total: 33.4s	remaining: 1.21s
# 193:	total: 33.5s	remaining: 1.04s
# 194:	total: 33.7s	remaining: 864ms
# 195:	total: 33.9s	remaining: 691ms
# 196:	total: 34s	remaining: 518ms
# 197:	total: 34.2s	remaining: 346ms
# 198:	total: 34.4s	remaining: 173ms
# 199:	total: 34.6s	remaining: 0us

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.25969965559112906
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.330722967651864

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)
print("{},{}".format(x_train.shape, x_test.shape))
# Out:
# (307511, 4),(48744, 4)
